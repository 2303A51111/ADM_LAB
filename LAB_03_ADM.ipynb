# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51111/ADM_LAB/blob/main/LAB_03_ADM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
iris=load_iris()
x=iris.data
y=iris.target

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
pca=PCA(n_components=2)
x_pca=pca.fit_transform(x_scaled)

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=y,cmap='viridis',edgecolor='k',s=100)
plt.title('PCA of iris dataset(2 components)')
plt.xlabel('principle component 1')
plt.ylabel('principle componenet 2')
plt.colorbar(label='traget class')
plt.show()

# %%
print("explained variance ratio of each component:")
print(pca.explained_variance_ratio_)
# Out:
# explained variance ratio of each component:
# [0.72962445 0.22850762]

# %%
pca=PCA(n_components=3)
x_pca = pca.fit_transform(x_scaled)

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig=plt.figure(figsize=(10,8))
ax=fig.add_subplot(111,projection='3d')
ax.scatter(x_pca[:,0],x_pca[:,1],x_pca[:,2],c=y,cmap='viridis',edgecolor='k',s=100)
ax.set_title('PCA of iris dataset(3 components)')
ax.set_xlabel('principle component 1')
ax.set_ylabel('principle component 2')
ax.set_zlabel('principle component 3')
plt.show()
